# %%
from pathlib import Path
import pandas as pd

file = Path(r"C:\Users\zek\Desktop\fiels\1.2.5 cutoff/2/SrTiO3_1_0.data")
data = pd.read_csv(file, delimiter=" ")
# Out:
# C:\Users\zek\AppData\Local\Temp\ipykernel_1356\1689232568.py:5: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file, delimiter=" ")

# %%
atom_data = data.iloc[10:int(data.iloc[0,0]) + 10,0:9]
atom_data.columns = ["index", "Atom", "Charge", "x", "y", "z","x_velocity","y_veloctiy", "z_velocity"]
atom_data.set_index("index", inplace=True)

# %%
atom_data
# Out:
#       Atom             Charge                  x          y        z  \
# index
# 1        3  -1.20014007628066  663.6594286792918  45.597218  13.8075
# 2        1   1.19962691207561  663.6249152137616  43.625020  11.8350
# 3        3  -1.20014007628066  661.6872306489973  45.631732  11.8350
# 4        3  -1.20014007628066  661.6527171834672  43.659534  13.8075
# 5        3  -1.20014007628066  659.7150326187029  45.666245  13.8075
# ...    ...                ...                ...        ...      ...
# 80348  2.0            2.39972         535.328503  39.951802  13.8075
# 80349  3.0           -1.20014         533.356305  39.986315  13.8075
# 80350  3.0           -1.20014         535.293989  37.979604  13.8075
# 80351  3.0           -1.20014         535.328503  39.951802  11.8350
# 80352  1.0           1.199627         537.266187  37.945090  11.8350
#
#        x_velocity  y_veloctiy  z_velocity
# index
# 1             0.0         0.0         0.0
# 2             0.0         0.0         0.0
# 3             0.0         0.0         0.0
# 4             0.0         0.0         0.0
# 5             0.0         0.0         0.0
# ...           ...         ...         ...
# 80348         0.0         0.0         0.0
# 80349         0.0         0.0         0.0
# 80350         0.0         0.0         0.0
# 80351         0.0         0.0         0.0
# 80352         0.0         0.0         0.0
#
# [80352 rows x 8 columns]
